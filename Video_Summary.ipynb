# %%
# Python code to convert video to audio 
import moviepy.editor as mp 
  
# Insert Local Video File Path  
clip = mp.VideoFileClip(r"D:/Hyper-dimension/video.mp4") 
  
# Insert Local Audio File Path 
audio_clip = clip.audio.write_audiofile(r"D:/Hyper-dimension/Audio_file.wav")
# Out:
# chunk:   0%|                                                                | 3/7854 [00:00<06:31, 20.03it/s, now=None]
# MoviePy - Writing audio in D:/Hyper-dimension/Audio_file.wav
# MoviePy - Done.

# %%
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence
import speech_recognition as sr
r = sr.Recognizer()

# %%
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
text = get_large_audio_transcription("D:/Hyper-dimension/Audio_file.wav")
# Out:
# audio-chunks\chunk1.wav : Hello guys and welcome back to get fighting.
# audio-chunks\chunk2.wav : In this video you will see.
# audio-chunks\chunk3.wav : How we can convert our audio into text.
# audio-chunks\chunk4.wav : Using.
# audio-chunks\chunk5.wav : Speech recognition library.
# audio-chunks\chunk6.wav : So without wasting any time that's it started.
# audio-chunks\chunk7.wav : Before starting video i want to just tell you that.
# audio-chunks\chunk8.wav : I am using a different mike that is night of mine.
# audio-chunks\chunk9.wav : Your phone's into the audio will not be that loud.
# audio-chunks\chunk10.wav : But you can see from the code.
# audio-chunks\chunk11.wav : And understand it.
# audio-chunks\chunk12.wav : So.
# audio-chunks\chunk13.wav : First of all.
# audio-chunks\chunk14.wav : We need to install.
# audio-chunks\chunk15.wav : This.
# audio-chunks\chunk16.wav : Speech recognition library.
# audio-chunks\chunk17.wav : And.
# audio-chunks\chunk18.wav : A simple compound.
# audio-chunks\chunk19.wav : Twin scroll it is.
# audio-chunks\chunk20.wav : Pseudo.
# audio-chunks\chunk21.wav : Factory.
# Error:
# audio-chunks\chunk23.wav : Speech recognition.
# audio-chunks\chunk24.wav : Now if you are using python to version you can simply do pip install speech recognition.
# audio-chunks\chunk25.wav : But i am using python 3.
# audio-chunks\chunk26.wav : And noticed that this.
# audio-chunks\chunk27.wav : And all.
# Error:
# audio-chunks\chunk29.wav : In uppercase.
# audio-chunks\chunk30.wav : Now if you don't have this installed.
# audio-chunks\chunk31.wav : Earlier you might take.
# audio-chunks\chunk32.wav : Some time to install it but for me it says requirement already satisfied.
# audio-chunks\chunk33.wav : So.
# audio-chunks\chunk34.wav : Let's jump into the coding part.
# audio-chunks\chunk35.wav : First we have to import.
# audio-chunks\chunk36.wav : Speech recognition.
# audio-chunks\chunk37.wav : Al asr.
# audio-chunks\chunk38.wav : Notice that here we have speech recognition.
# audio-chunks\chunk39.wav : In this format where as.
# audio-chunks\chunk40.wav : Install it in this week.
# audio-chunks\chunk41.wav : Do you need to have.
# audio-chunks\chunk42.wav : I looked around.
# audio-chunks\chunk43.wav : The cases because this is case sensitive.
# audio-chunks\chunk44.wav : Now we have used.
# audio-chunks\chunk45.wav : As notation because.
# audio-chunks\chunk46.wav : Writing speech recognition whole every time.
# audio-chunks\chunk47.wav : Bb.
# audio-chunks\chunk48.wav : Not.
# audio-chunks\chunk49.wav : A good.
# audio-chunks\chunk50.wav : Not a good way.
# audio-chunks\chunk51.wav : So.
# audio-chunks\chunk52.wav : This is the only library that we need.
# audio-chunks\chunk53.wav : Now.
# audio-chunks\chunk54.wav : We have to initialise our is equal to.
# audio-chunks\chunk55.wav : Sr dot.
# audio-chunks\chunk56.wav : Now this will work as a recognizer to recognise our audio so with.
# Error:
# audio-chunks\chunk58.wav : Essar.
# audio-chunks\chunk59.wav : Dot.
# audio-chunks\chunk60.wav : Microphone.
# audio-chunks\chunk61.wav : As.
# audio-chunks\chunk62.wav : Source.
# audio-chunks\chunk63.wav : Which means that we are initialising.
# audio-chunks\chunk64.wav : Power source.
# audio-chunks\chunk65.wav : Tu.
# audio-chunks\chunk66.wav : Sr dot microphone.
# audio-chunks\chunk67.wav : You can also use some audio files.
# audio-chunks\chunk68.wav : To convert sex.
# audio-chunks\chunk69.wav : Convert into text but in this video will be using.
# audio-chunks\chunk70.wav : This.
# audio-chunks\chunk71.wav : Microphone.
# audio-chunks\chunk72.wav : White.
# audio-chunks\chunk73.wav : So let's just print a normal command enter.
# Error:
# audio-chunks\chunk75.wav : Anything for.
# Error:
# audio-chunks\chunk77.wav : Speak anything.
# audio-chunks\chunk78.wav : Unnao.
# audio-chunks\chunk79.wav : We have to use.
# Error:
# audio-chunks\chunk81.wav : I dot listen command.
# audio-chunks\chunk82.wav : And we have to listen to the source.
# audio-chunks\chunk83.wav : So.
# audio-chunks\chunk84.wav : It will listen to the source and save it in audio.
# Error:
# audio-chunks\chunk86.wav : So now we have a audio player.
# audio-chunks\chunk87.wav : Now.
# audio-chunks\chunk88.wav : I am just keeping this hole inside a try and except clause.
# audio-chunks\chunk89.wav : Let's see this without it.
# audio-chunks\chunk90.wav : So.
# audio-chunks\chunk91.wav : Our text will be.
# audio-chunks\chunk92.wav : Idot.
# audio-chunks\chunk93.wav : Recognise google now we have various options recognised in google ibm excetra but for this one will be using recognise google.
# audio-chunks\chunk94.wav : And.
# audio-chunks\chunk95.wav : We have to pass our audio.
# audio-chunks\chunk96.wav : This will convert.
# audio-chunks\chunk97.wav : Is audio into text.
# audio-chunks\chunk98.wav : Now we just have to print.
# audio-chunks\chunk99.wav : You said.
# Error:
# Error:
# audio-chunks\chunk102.wav : In.com mat.
# audio-chunks\chunk103.wav : Text.
# audio-chunks\chunk104.wav : Set me paint like you said.
# audio-chunks\chunk105.wav : And whatever you said he will be here.
# audio-chunks\chunk106.wav : Now.
# audio-chunks\chunk107.wav : Remember my mentioned train accept now it may happen sometimes that the audio is not clear.
# audio-chunks\chunk108.wav : And you might not.
# audio-chunks\chunk109.wav : Catch it correctly.
# audio-chunks\chunk110.wav : So.
# audio-chunks\chunk111.wav : We can put it in a try.
# audio-chunks\chunk112.wav : And.
# audio-chunks\chunk113.wav : In the except block.
# audio-chunks\chunk114.wav : We can just write.
# audio-chunks\chunk115.wav : Sorry.
# audio-chunks\chunk116.wav : Could not.
# audio-chunks\chunk117.wav : Recognise.
# audio-chunks\chunk118.wav : Your voice.
# audio-chunks\chunk119.wav : So.
# audio-chunks\chunk120.wav : I am just repeating the steps again.
# audio-chunks\chunk121.wav : What's first we have to import the library.
# audio-chunks\chunk122.wav : When we have to initialise our recognizer.
# audio-chunks\chunk123.wav : Then.
# audio-chunks\chunk124.wav : We have to mention source.
# audio-chunks\chunk125.wav : And this can be.
# Error:
# audio-chunks\chunk127.wav : Sr dot microphone or it can be an audio file.
# audio-chunks\chunk128.wav : Now.
# audio-chunks\chunk129.wav : We have to listen.
# audio-chunks\chunk130.wav : To the source.
# audio-chunks\chunk131.wav : Then we have to.
# audio-chunks\chunk132.wav : Use.
# audio-chunks\chunk133.wav : Recognizer.
# audio-chunks\chunk134.wav : Convert our audio into.
# audio-chunks\chunk135.wav : Text path.
# audio-chunks\chunk136.wav : Thanks.
# audio-chunks\chunk137.wav : In case if the audio is not identified correctly.
# audio-chunks\chunk138.wav : We can just use and except clause.
# audio-chunks\chunk139.wav : And that sorry we couldn't recognise your voice.
# audio-chunks\chunk140.wav : Now let's see how this works.
# Error:
# audio-chunks\chunk142.wav : So i am saying hello.
# audio-chunks\chunk143.wav : Mp.
# audio-chunks\chunk144.wav : We got it correctly so.
# audio-chunks\chunk145.wav : This was all in speech recognition.
# audio-chunks\chunk146.wav : Library.
# audio-chunks\chunk147.wav : And in this way we can convert audio into text part.
# audio-chunks\chunk148.wav : So that it from the video guys.
# audio-chunks\chunk149.wav : The next video.
# audio-chunks\chunk150.wav : Till then stay tuned by and.
# audio-chunks\chunk151.wav : Have fun with python.

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
#from spacy.en import English
from spacy.lang.en import English

# %%
extra_words=list(STOP_WORDS)+list(punctuation)+['\n']
nlp=spacy.load('en_core_web_sm')
docx = nlp(text)

# %%
all_words=[word.text for word in docx]
Freq_word={}
for w in all_words:
    w1=w.lower()
    if w1 not in extra_words and w1.isalpha():
        if w1 in Freq_word.keys():
            Freq_word[w1]+=1
        else:
            Freq_word[w1]=1

# %%
Freq_word
# Out:
# {'hello': 2,
#  'guys': 2,
#  'welcome': 1,
#  'fighting': 1,
#  'video': 5,
#  'convert': 6,
#  'audio': 13,
#  'text': 7,
#  'speech': 8,
#  'recognition': 8,
#  'library': 5,
#  'wasting': 1,
#  'time': 3,
#  'started': 1,
#  'starting': 1,
#  'want': 1,
#  'tell': 1,
#  'different': 1,
#  'mike': 1,
#  'night': 1,
#  'phone': 1,
#  'loud': 1,
#  'code': 1,
#  'understand': 1,
#  'need': 3,
#  'install': 4,
#  'simple': 1,
#  'compound': 1,
#  'twin': 1,
#  'scroll': 1,
#  'pseudo': 1,
#  'factory': 1,
#  'python': 3,
#  'version': 1,
#  'simply': 1,
#  'pip': 1,
#  'noticed': 1,
#  'uppercase': 1,
#  'installed': 1,
#  'earlier': 1,
#  'says': 1,
#  'requirement': 1,
#  'satisfied': 1,
#  'let': 4,
#  'jump': 1,
#  'coding': 1,
#  'import': 2,
#  'al': 1,
#  'asr': 1,
#  'notice': 1,
#  'format': 1,
#  'week': 1,
#  'looked': 1,
#  'cases': 1,
#  'case': 2,
#  'sensitive': 1,
#  'notation': 1,
#  'writing': 1,
#  'bb': 1,
#  'good': 2,
#  'way': 2,
#  'initialise': 2,
#  'equal': 1,
#  'sr': 3,
#  'dot': 5,
#  'work': 1,
#  'recognizer': 3,
#  'recognise': 5,
#  'essar': 1,
#  'microphone': 4,
#  'source': 6,
#  'means': 1,
#  'initialising': 1,
#  'power': 1,
#  'tu': 1,
#  'use': 4,
#  'files': 1,
#  'sex': 1,
#  'white': 1,
#  'print': 2,
#  'normal': 1,
#  'command': 2,
#  'enter': 1,
#  'speak': 1,
#  'unnao': 1,
#  'listen': 4,
#  'save': 1,
#  'player': 1,
#  'keeping': 1,
#  'hole': 1,
#  'inside': 1,
#  'try': 2,
#  'clause': 2,
#  'idot': 1,
#  'google': 3,
#  'options': 1,
#  'recognised': 1,
#  'ibm': 1,
#  'excetra': 1,
#  'pass': 1,
#  'said': 3,
#  'mat': 1,
#  'set': 1,
#  'paint': 1,
#  'like': 1,
#  'remember': 1,
#  'mentioned': 1,
#  'train': 1,
#  'accept': 1,
#  'happen': 1,
#  'clear': 1,
#  'catch': 1,
#  'correctly': 3,
#  'block': 1,
#  'write': 1,
#  'sorry': 2,
#  'voice': 2,
#  'repeating': 1,
#  'steps': 1,
#  'mention': 1,
#  'file': 1,
#  'path': 1,
#  'thanks': 1,
#  'identified': 1,
#  'works': 1,
#  'saying': 1,
#  'mp': 1,
#  'got': 1,
#  'till': 1,
#  'stay': 1,
#  'tuned': 1,
#  'fun': 1}

# %%
val=sorted(Freq_word.values())
max_freq=val[-4:]
print("Topic of document given :-")
for word,freq in Freq_word.items():
    if freq in max_freq:
        print(word ,end=" ")
    else:
        continue
# Out:
# Topic of document given :-
# audio text speech recognition

# %%
for word in Freq_word.keys():
       Freq_word[word] = (Freq_word[word]/max_freq[-1])

# %%
sent_strength={}
for sent in docx.sents:
    for word in sent :
        if word.text.lower() in Freq_word.keys():
            if sent in sent_strength.keys():
                sent_strength[sent]+=Freq_word[word.text.lower()]
            else:
                sent_strength[sent]=Freq_word[word.text.lower()]
        else:
            continue

# %%
sent_strength
# Out:
# {Hello guys and welcome back to get fighting.: 0.46153846153846156,
#  In this video you will see.: 0.38461538461538464,
#  How we can convert our audio into text.: 2.0,
#  Speech recognition library.: 1.6153846153846154,
#  So without wasting any time that's it started.: 0.38461538461538464,
#  Before starting video i want to just tell you that.: 0.6153846153846154,
#  I am using a different mike that is night of mine.: 0.23076923076923078,
#  Your phone's into the audio will not be that loud.: 1.1538461538461537,
#  But you can see from the code.: 0.07692307692307693,
#  And understand it.: 0.07692307692307693,
#  We need to install.: 0.5384615384615385,
#  Speech recognition library.: 1.6153846153846154,
#  A simple compound.: 0.15384615384615385,
#  Twin scroll it is.: 0.15384615384615385,
#  Pseudo.: 0.07692307692307693,
#  Factory.: 0.07692307692307693,
#  Speech recognition.: 1.2307692307692308,
#  Now if you are using python to version you can simply do pip install speech recognition.: 2.0,
#  But i am using python 3.: 0.23076923076923078,
#  And noticed that this.: 0.07692307692307693,
#  In uppercase.: 0.07692307692307693,
#  Now if you don't have this installed.: 0.07692307692307693,
#  Earlier you might take.: 0.07692307692307693,
#  Some time to install it: 0.5384615384615385,
#  but for me it says requirement already satisfied.: 0.23076923076923078,
#  Let's jump into the coding part.: 0.46153846153846156,
#  First we have to import.: 0.15384615384615385,
#  Speech recognition.: 1.2307692307692308,
#  Al asr.: 0.15384615384615385,
#  Notice that here we have speech recognition.: 1.3076923076923077,
#  In this format where as.: 0.07692307692307693,
#  Install it in this week.: 0.38461538461538464,
#  Do you need to have.: 0.23076923076923078,
#  I looked around.: 0.07692307692307693,
#  The cases because this is case sensitive.: 0.3076923076923077,
#  As notation because.: 0.07692307692307693,
#  Writing speech recognition whole every time.: 1.5384615384615385,
#  Bb.: 0.07692307692307693,
#  A good.: 0.15384615384615385,
#  Not a good way.: 0.3076923076923077,
#  This is the only library that we need.: 0.6153846153846154,
#  We have to initialise our is equal to.: 0.23076923076923078,
#  Sr dot.: 0.6153846153846154,
#  Now this will work as a recognizer to recognise our audio so with.: 1.6923076923076923,
#  Essar.: 0.07692307692307693,
#  Dot.: 0.38461538461538464,
#  Microphone.: 0.3076923076923077,
#  Source.: 0.46153846153846156,
#  Which means that we are initialising.: 0.15384615384615385,
#  Power source.: 0.5384615384615385,
#  Tu.: 0.07692307692307693,
#  Sr dot microphone.: 0.9230769230769231,
#  You can also use some audio files.: 1.3846153846153846,
#  To convert sex.: 0.5384615384615385,
#  Convert into text but in this video will be using.: 1.3846153846153846,
#  Microphone.: 0.3076923076923077,
#  White.: 0.07692307692307693,
#  So let's just print a normal command enter.: 0.7692307692307694,
#  Speak anything.: 0.07692307692307693,
#  Unnao.: 0.07692307692307693,
#  We have to use.: 0.3076923076923077,
#  I dot listen command.: 0.8461538461538461,
#  And we have to listen to the source.: 0.7692307692307693,
#  It will listen to the source and save it in audio.: 1.8461538461538463,
#  So now we have a audio player.: 1.0769230769230769,
#  I am just keeping this hole inside a try and except clause.: 0.5384615384615385,
#  Let's see this without it.: 0.3076923076923077,
#  Our text will be.: 0.5384615384615384,
#  Idot.: 0.07692307692307693,
#  Recognise google now we have various options recognised in google ibm excetra but for this one will be using recognise google.: 1.7692307692307692,
#  We have to pass our audio.: 1.0769230769230769,
#  This will convert.: 0.46153846153846156,
#  Is audio into text.: 1.5384615384615383,
#  Now we just have to print.: 0.15384615384615385,
#  You said.: 0.23076923076923078,
#  In.com mat.: 0.07692307692307693,
#  Text.: 0.5384615384615384,
#  Set me paint like you said.: 0.46153846153846156,
#  And whatever you said he will be here.: 0.23076923076923078,
#  Remember my mentioned train accept now it may happen sometimes that the audio is not clear.: 1.4615384615384615,
#  Catch it correctly.: 0.3076923076923077,
#  We can put it in a try.: 0.15384615384615385,
#  In the except block.: 0.07692307692307693,
#  We can just write.: 0.07692307692307693,
#  Sorry.: 0.15384615384615385,
#  Recognise.: 0.38461538461538464,
#  Your voice.: 0.15384615384615385,
#  I am just repeating the steps again.: 0.15384615384615385,
#  What's first we have to import the library.: 0.5384615384615385,
#  When we have to initialise our recognizer.: 0.38461538461538464,
#  We have to mention source.: 0.5384615384615385,
#  Sr dot microphone or: 0.9230769230769231,
#  it can be an audio file.: 1.0769230769230769,
#  We have to listen.: 0.3076923076923077,
#  To the source.: 0.46153846153846156,
#  Use.: 0.3076923076923077,
#  Recognizer.: 0.23076923076923078,
#  Convert our audio into.: 1.4615384615384617,
#  Text path.: 0.6153846153846154,
#  Thanks.: 0.07692307692307693,
#  In case if the audio is not identified correctly.: 1.4615384615384615,
#  We can just use and except clause.: 0.46153846153846156,
#  And that sorry we couldn't recognise your voice.: 0.6923076923076924,
#  Now let's see how this works.: 0.38461538461538464,
#  So i am saying hello.: 0.23076923076923078,
#  Mp.: 0.07692307692307693,
#  We got it correctly so.: 0.3076923076923077,
#  This was all in speech recognition.: 1.2307692307692308,
#  Library.: 0.38461538461538464,
#  And in this way we can convert audio into text part.: 2.1538461538461537,
#  So that it from the video guys.: 0.5384615384615385,
#  The next video.: 0.38461538461538464,
#  Till then stay tuned by and.: 0.23076923076923078,
#  Have fun with python.: 0.3076923076923077}

# %%
top_sentences=(sorted(sent_strength.values())[::-1])
top20percent_sentence=int(0.2*len(top_sentences))
top_sent=top_sentences[:top20percent_sentence]

# %%
summary=[]
for sent,strength in sent_strength.items():
    if strength in top_sent:
        summary.append(sent)
    else:
        continue

# %%
for i in summary:
    print(i,end="")
# Out:
# How we can convert our audio into text.Speech recognition library.Your phone's into the audio will not be that loud.Speech recognition library.Speech recognition.Now if you are using python to version you can simply do pip install speech recognition.Speech recognition.Notice that here we have speech recognition.Writing speech recognition whole every time.Now this will work as a recognizer to recognise our audio so with.You can also use some audio files.Convert into text but in this video will be using.It will listen to the source and save it in audio.So now we have a audio player.Recognise google now we have various options recognised in google ibm excetra but for this one will be using recognise google.We have to pass our audio.Is audio into text.Remember my mentioned train accept now it may happen sometimes that the audio is not clear.it can be an audio file.Convert our audio into.In case if the audio is not identified correctly.This was all in speech recognition.And in this way we can convert audio into text part.
